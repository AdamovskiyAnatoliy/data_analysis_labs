# %%
import numpy as np
import pywt
from tqdm import tqdm_notebook
import matplotlib.pyplot as plt

# %matplotlib inline

# %% [markdown]
# ## Завдання А

# %% [markdown]
# ### Вейвлет Хаара

# %%
def base_haar_wavelet(x):
    return 1 if 0 <= x < 1/2 else -1 if 1/2 <= x < 1 else 0

# %%
x = np.arange(-1, 2 , 0.1)
y = list(map(base_haar_wavelet, x))
plt.grid(True)
plt.title('Вейвлет Хаара')
plt.xlabel('$x$')
plt.ylabel('$y$')
plt.step(x, y);

# %% [markdown]
# ### Вейвлет Шенона

# %%
def base_shannon_wavelet(x):
    return np.sin(np.pi * x) / (np.pi * x)

# %%
x = np.arange(-10, 10 , 0.1)
y = list(map(base_shannon_wavelet, x))

# %%
plt.grid(True)
plt.title('Вейвлет Шенона')
plt.xlabel('$x$')
plt.ylabel('$y$')
plt.plot(x, y);

# %% [markdown]
# ### Вейвлет Гаусса

# %%
def base_gaussian_wavelet(x):
    return np.exp((-x**2)/2)

# %%
x = np.arange(-5, 5 , 0.1)
y = list(map(base_gaussian_wavelet, x))

# %%
plt.grid(True)
plt.title('Вейвлет Гаусса')
plt.xlabel('$x$')
plt.ylabel('$y$')
plt.plot(x, y);

# %% [markdown]
# ## Завдання Б

# %%
num_group = 20 # 51
num_student = 1
n = int(num_group / 2)
N = 2**n 

M = num_student
M1 = N

# %%
s1 = 2 * np.random.rand(N) + \
         num_group * np.cos(2 * num_student * np.pi * np.arange(N) / N)*(1+0.1*np.random.rand(N)) + \
         17 * np.cos(((4 * num_student * np.pi * np.arange(N))/N) + np.random.rand(N)) + \
         3 * np.cos((5 * num_student * np.pi * np.arange(N)) / N) * (np.random.rand(N)+num_group)

# %%
plt.figure(figsize=(20, 16))
plt.plot(np.arange(len(s1)), s1);

# %%
def f2(j, k, x):
    return (2 ** (j)) * base_haar_wavelet((2**j) * x - k)

# %% [markdown]
# ### Вейвлет Хаара

# %%
g1 = base_haar_wavelet
def f2(j, k, x):
    return (2 ** (j/2)) * g1((2**j) * x - k)

# %%
W = np.zeros((M, M1))
for l in tqdm_notebook(range(M)):
    for j in tqdm_notebook(range(M1)):        
        res = 0
        for i in range(N):
            res += s1[i] * f2(l, j, i)
        W[l, j] = res
# Out:
# A Jupyter Widget
# A Jupyter Widget

# %%
W.max(axis=0)
# Out:
# array([ 98.1818029 ,  94.81368864,  99.3289961 , ..., -22.98850047,
#        -30.67234255, -21.6299307 ])

# %%
plt.figure(figsize=(20, 10))
plt.imshow(W);

# %%
d = []
for i in tqdm_notebook(range(N)):
    res = 0
    for l in range(M):
        for j in range(M1):
            res += W[l, j] * f2(l, j, i) / (2**(2*l))
    d.append(res)
# Out:
# A Jupyter Widget

# %%
W
# Out:
# array([[ 98.1818029 ,  94.81368864,  99.3289961 , ..., -22.98850047,
#         -30.67234255, -21.6299307 ]])

# %%
d - s1
# Out:
# array([ 0.,  0.,  0., ...,  0.,  0.,  0.])

# %%
plt.plot(np.arange(len(d)), d);

# %%
plt.plot(np.arange(len(s1)), s1);

# %%
len(s1)
# Out:
# 256

# %% [markdown]
# ### Вейвлет Шенона

# %% [markdown]
# ### Вейвлет Гаусса
